# %%
import openai

# get API key from top-right dropdown on OpenAI website
openai.api_key = "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"

query = "who was the 12th person on the moon and when did they land?"

def complete(prompt):
    # query text-davinci-003
    res = openai.Completion.create(
        engine='text-davinci-003',
        prompt=prompt,
        temperature=0,
        max_tokens=400,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=None
    )
    return res['choices'][0]['text'].strip()

query = (
    "Which training method should I use for sentence transformers when " +
    "I only have pairs of related sentences?"
)

print(complete(query))

embed_model = "text-embedding-ada-003"

res = openai.Embedding.create(
    input=[
        "Sample document text goes here",
        "there will be several phrases in each batch"
    ], engine=embed_model
)
res.keys()
len(res['data'])
# Out:
# If you only have pairs of related sentences, you should use the pairwise training method.
# 2

# %%
from youtube_transcript_api import YouTubeTranscriptApi

from datasets import load_dataset
video_ids = [
    "HB3RI14DZMQ", 
    "HW2V3O5HY0A", 
    "6ZBO7j_FVnc" , 
    "35PaaKLsLLQ", 
    "qWHnIPvvfw0", 
]
data_transcripts = []
for vid_id in video_ids:
    
    data_transcripts.append(YouTubeTranscriptApi.get_transcript(vid_id))
data_transcripts
# Out:
# [[{'text': "what's up everybody peter mckinnon here",
#    'start': 1.68,
#    'duration': 2.48},
#   {'text': 'welcome back to', 'start': 3.28, 'duration': 3.44},
#   {'text': "yet another video and folks today we're",
#    'start': 4.16,
#    'duration': 13.76},
#   {'text': 'talking about the canon r5', 'start': 6.72, 'duration': 11.2},
#   {'text': '[Music]', 'start': 18.12, 'duration': 3.149},
#   {'text': 'the highly anticipated much discussed',
#    'start': 21.279,
#    'duration': 5.84},
#   {'text': 'rumored all the buzz and for a very good',
#    'start': 24.32,
#    'duration': 4.48},
#   {'text': 'reason because this camera', 'start': 27.119, 'duration': 3.521},
#   {'text': "delivers i couldn't be more excited",
#    'start': 28.8,
#    'duration': 3.2},
#   {'text': 'about it now before we dive into this',
#    'start': 30.64,
#    'duration': 3.04},
#   {'text': 'thing and i talk about my experience and',
#    'start': 32.0,
#    'duration': 3.12},
# ...

# %%
texts = []
for data in data_transcripts:
    text = ''
    for timestamps  in data:
        text += " " +  timestamps['text']
    texts.append(text)
texts
# Out:
# [" what's up everybody peter mckinnon here welcome back to yet another video and folks today we're talking about the canon r5 [Music] the highly anticipated much discussed rumored all the buzz and for a very good reason because this camera delivers i couldn't be more excited about it now before we dive into this thing and i talk about my experience and show you some footage because i have been shooting with it for a few months now canon sent me this camera on loan i'm giving it back actually in a few hours to test out basically in the middle of the pandemic but i want you to know too right at the beginning i'm sponsored by canon i'm an ambassador for the brand i'm a canon shooter i've been a canon shooter my entire life i've been shooting canon since i bought my first professional dslr that's about 15 years now i've been using canon products so keep that in mind when i'm doing this review i'm not going to be unfair about it if there are things i don't like about it i'm going to tell 
# ...

# %%
v2 = {'start': 0.0,
 'end': 780.00,
 'title': 'Hands ON with the NEW CANON EOS R5! THE GRAIL CAMERA!',
 'text': texts[0],
 'id': 'HB3RI14DZMQ',
 'url': 'https://youtu.be/HB3RI14DZMQ',
 'published': '2022-07-24 13:00:03 UTC',
 'channel_id': 'UxCBJycsmduvYEL83R_U4JriQ'}

v3 = {'start': 0.0,
 'end': 780.00,
 'title': 'Canon R5 vs R6 Long Term Review: Which is actually BETTER in 2022?',
 'text': texts[1],
 'id': 'HW2V3O5HY0A',
 'url': 'https://youtu.be/HW2V3O5HY0A',
 'published': '2023-01-23 13:00:03 UTC',
 'channel_id': 'UCBJycsmduxvYEL83R_U4JriQ'}

v4 = {'start': 0.0,
 'end': 720.00,
 'title': 'Which MacBook Should You Buy in 2023? (Avoid These Ones)',
 'text': texts[2],
 'id': '6ZBO7j_FVnc',
 'url': 'https://www.youtube.com/watch?v=6ZBO7j_FVnc',
 'published': '2022-08-09 13:00:03 UTC',
 'channel_id': 'UCBJycsmduvYEL8x3R_U4JriQ'}

v5 = {'start': 0.0,
 'end': 780.00,
 'title': 'Canon R5 - What I Wish I Knew BEFORE Buying the Canon EOS R5',
 'text': texts[3],
 'id': '35PaaKLsLLQ',
 'url': 'https://www.youtube.com/watch?v=35PaaKLsLLQ',
 'published': '2022-08-09 13:00:03 UTC',
 'channel_id': 'UCBJycsmduvYELx83R_U4JriQ'}

v6 = {'start': 0.0,
 'end': 840.00,
 'title': "Canon's Best Camera in 2023?! Canon R5 Review with Sample",
 'text': texts[4],
 'id': 'qWHnIPvvfw0',
 'url': 'https://www.youtube.com/watch?v=qWHnIPvvfw0',
 'published': '2022-08-09 13:00:03 UTC',
 'channel_id': 'UCBJycsmduvYEL83R_U4JxriQ'}

# %%
# from tqdm.auto import tqdm

# new_data = []

# window = 20  # number of sentences to combine
# stride = 4  # number of sentences to 'stride' over, used to create overlap

# for i in tqdm(range(0, len(data), stride)):
#     i_end = min(len(data)-1, i+window)
#     if data[i]['title'] != data[i_end]['title']:
#         # in this case we skip this entry as we have start/end of two videos
#         continue
#     text = ' '.join(data[i:i_end]['text'])
#     # create the new merged dataset
#     new_data.append({
#         'start': data[i]['start'],
#         'end': data[i_end]['end'],
#         'title': data[i]['title'],
#         'text': text,
#         'id': data[i]['id'],
#         'url': data[i]['url'],
#         'published': data[i]['published'],
#         'channel_id': data[i]['channel_id']
#     })
new_data = [v2,v3,v4,v5,v6]

# %%
new_data[0]
# Out:
# {'start': 0.0,
#  'end': 780.0,
#  'title': 'Hands ON with the NEW CANON EOS R5! THE GRAIL CAMERA!',
# ...

# %%
len(new_data)
# Out:
# 5

# %%
import pinecone

pinecone.init(
    api_key="09890b7f-3119-4d98-924b-bb2ded7b9b52",
    environment="us-west4-gcp"
)
pinecone.list_indexes()
# Out:
# []

# %%
# import pinecone

index_name = 'openaiyoutube'

# initialize connection to pinecone (get API key at app.pinecone.io)
pinecone.init(
    api_key="09890b7f-3119-4d98-924b-bb2ded7b9b52",
    environment="us-west4-gcp"
)

# check if index already exists (it shouldn't if this is first time)
if index_name not in pinecone.list_indexes():
    # if does not exist, create index
    pinecone.create_index(
        index_name,
        dimension=len(res['data'][0]['embedding']),
        metric='cosine',
        metadata_config={'indexed': ['channel_id', 'published']}
    )
# connect to index
index = pinecone.Index(index_name)
# view index stats

# %%
index.describe_index_stats()
# pinecone.delete_index('openai-youtube-canon-transcriptions-a5')
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %%
from tqdm.auto import tqdm
import datetime
from time import sleep

batch_size = 100  # how many embeddings we create and insert at once

for i in tqdm(range(0, len(new_data)//2, batch_size)):
    # find end of batch
    i_end = min(len(new_data), i+batch_size)
    meta_batch = new_data[i:i_end]
    # get ids
    ids_batch = [x['channel_id'] for x in meta_batch]
    # get texts to encode
    texts = [x['text'] for x in meta_batch]
    # create embeddings (try-except added to avoid RateLimitError)
    try:
        res = openai.Embedding.create(input=texts, engine=embed_model)
    except:
        done = False
        while not done:
            sleep(5)
            try:
                res = openai.Embedding.create(input=texts, engine=embed_model)
                done = True
            except:
                pass
    embeds = [record['embedding'] for record in res['data']]
    # cleanup metadata
    meta_batch = [{
        'start': x['start'],
        'end': x['end'],
        'title': x['title'],
        'text': x['text'],
        'url': x['url'],
        'published': x['published'],
        'channel_id': x['channel_id']
    } for x in meta_batch]
    to_upsert = list(zip(ids_batch, embeds, meta_batch))
    # upsert to Pinecone
    index.upsert(vectors=to_upsert)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
res = openai.Embedding.create(
    input=[query],
    engine=embed_model
)

# retrieve from Pinecone
xq = res['data'][0]['embedding']

# get relevant contexts (including the questions)
res = index.query(xq, top_k=2, include_metadata=True)

# %%
limit = 3750

def retrieve(query):
    res = openai.Embedding.create(
        input=[query],
        engine=embed_model
    )

    # retrieve from Pinecone
    xq = res['data'][0]['embedding']

    # get relevant contexts
    res = index.query(xq, top_k=3, include_metadata=True)
    contexts = [
        x['metadata']['text'] for x in res['matches']
    ]

    # build our prompt with the retrieved contexts included
    prompt_start = (
        "Answer the question based on the context below.\n\n"+
        "Context:\n"
    )
    prompt_end = (
        f"\n\nQuestion: {query}\nAnswer:"
    )
    print("cc",contexts)
    
    # append contexts until hitting limit
    # for i in range(0, len(contexts)):
    #     if len("\n\n---\n\n".join(contexts[:i])) >= limit:
    #         prompt = (
    #             prompt_start +
    #             "\n\n---\n\n".join(contexts[:i-1]) +
    #             prompt_end
    #         )
    #         break
    #     elif i == len(contexts)-1:
    #         prompt = (
    #             prompt_start +
    #             "\n\n---\n\n".join(contexts) +
    #             prompt_end
    #         )
    prompt = prompt_start + contexts[0] + prompt_end
    return prompt

# %%
def ask_me(prompt):
    query = prompt
    query_with_contexts = retrieve(query)
    print(query_with_contexts)
    return complete(query_with_contexts)

# %%
ask_me("what are a few things about canon r5")
# Out:
# cc [" what's up everybody peter mckinnon here welcome back to yet another video and folks today we're talking about the canon r5 [Music] the highly anticipated much discussed rumored all the buzz and for a very good reason because this camera delivers i couldn't be more excited about it now before we dive into this thing and i talk about my experience and show you some footage because i have been shooting with it for a few months now canon sent me this camera on loan i'm giving it back actually in a few hours to test out basically in the middle of the pandemic but i want you to know too right at the beginning i'm sponsored by canon i'm an ambassador for the brand i'm a canon shooter i've been a canon shooter my entire life i've been shooting canon since i bought my first professional dslr that's about 15 years now i've been using canon products so keep that in mind when i'm doing this review i'm not going to be unfair about it if there are things i don't like about it i'm going to te
# ...
